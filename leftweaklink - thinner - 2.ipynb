# %%
# %config InlineBackend.figure_formats = {"retina", "png"}

import os
import tempfile

os.environ["OPENBLAS_NUM_THREADS"] = "1"

from IPython.display import HTML, display
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.sparse as sp

plt.rcParams["figure.figsize"] = (5, 4)

import tdgl
from tdgl.geometry import box, circle
from tdgl.visualization.animate import create_animation
from tdgl import TDGLSolver,SolverResult
from tdgl.geometry import box
from tdgl.solver.runner import DataHandler, Runner
from tdgl.solution.solution import Solution
from tdgl.solver.options import SparseSolver
import itertools
import logging
logger = logging.getLogger("solver")
from datetime import datetime

from scipy.signal import find_peaks
#plt.rcParams['animation.ffmpeg_path'] = "C:\\FFmpeg\\bin\\ffmpeg"

np.set_printoptions(linewidth=100)

# %%
MAKE_ANIMATIONS = True
tempdir = tempfile.TemporaryDirectory()
tempdir
# Out:
# <TemporaryDirectory 'C:\\Users\\CARISS~1\\AppData\\Local\\Temp\\tmppvvkgfwr'>

# %%
def make_video_from_solution(
    solution,
    quantities=("order_parameter", "phase"),
    fps=20,
    figsize=(5, 4),
):
    """Generates an HTML5 video from a tdgl.Solution."""
    with tdgl.non_gui_backend():
        with h5py.File(solution.path, "r") as h5file:
            anim = create_animation(
                h5file,
                quantities=quantities,
                fps=fps,
                figure_kwargs=dict(figsize=figsize),
            )
            video = anim.to_html5_video()
        return HTML(video)

# %%
class TDGLSolverFluc(TDGLSolver):
    def __init__(self, device, options, applied_vector_potential = 0.0, terminal_currents =  None, disorder_epsilon = 1.0, seed_solution = None, T = 0):
        super().__init__(device, options, applied_vector_potential, terminal_currents,disorder_epsilon, seed_solution)
        self.T = T
    
    def therm_fluc(self):
        T= self.T
        therm =  np.zeros([len(self.sites),]) 
        if T==0:
            return therm
        sd = np.sqrt(4*5.79*np.sqrt(2)*10**(-4)*T/(1-T))

        therm =  np.array(np.random.normal(loc=0,scale=sd,size=[len(self.sites),]),dtype = 'complex')+\
                1j*np.array(np.random.normal(loc=0,scale=sd,size=[len(self.sites),]),dtype = 'complex')
        
        for t in self.terminal_info:
            therm[t.site_indices]=0
        return therm
    @staticmethod
    def solve_for_psi_squared(
        *,
        psi: np.ndarray,
        abs_sq_psi: np.ndarray,
        mu: np.ndarray,
        epsilon: np.ndarray,
        gamma: float,
        u: float,
        dt: float,
        T:float,
        therm:np.ndarray,
        psi_laplacian: sp.spmatrix,
    ):
        if isinstance(psi, np.ndarray):
            xp = np
        else:
            assert cupy is not None
            assert isinstance(psi, cupy.ndarray)
            xp = cupy
        U = xp.exp(-1j * mu * dt)
        z = U * gamma**2 / 2 * psi
        with np.errstate(all="raise"):
            try:
                w = z * abs_sq_psi + U * (
                    psi
                    + (dt / u)
                    * xp.sqrt(1 + gamma**2 * abs_sq_psi)
                    * ((epsilon - abs_sq_psi) * psi* (1-T)+therm + psi_laplacian @ psi)#modification
                )
                c = w.real * z.real + w.imag * z.imag
                two_c_1 = 2 * c + 1
                w2 = xp.absolute(w) ** 2
                discriminant = two_c_1**2 - 4 * xp.absolute(z) ** 2 * w2
            except Exception:
                logger.warning("Unable to solve for |psi|^2.", exc_info=True)
                return None
        if xp.any(discriminant < 0):
            return None
        new_sq_psi = (2 * w2) / (two_c_1 + xp.sqrt(discriminant))
        psi = w - z * new_sq_psi
        return psi, new_sq_psi

    def adaptive_euler_step(
        self,
        step: int,
        psi: np.ndarray,
        abs_sq_psi: np.ndarray,
        mu: np.ndarray,
        epsilon: np.ndarray,
        therm:np.ndarray,
        dt: float,
    ):
        options = self.options
        kwargs = dict(
            psi=psi,
            abs_sq_psi=abs_sq_psi,
            mu=mu,
            epsilon=epsilon,
            T=self.T,
            therm=therm,
            gamma=self.gamma,
            u=self.u,
            dt=dt,
            psi_laplacian=self.operators.psi_laplacian,
        )
        result = self.solve_for_psi_squared(**kwargs)
        for retries in itertools.count():
            if result is not None:
                break  # First evaluation of |psi|^2 was successful.
            if not options.adaptive or retries > options.max_solve_retries:
                raise RuntimeError(
                    f"Solver failed to converge in {options.max_solve_retries}"
                    f" retries at step {step} with dt = {dt:.2e}."
                    f" Try using a smaller dt_init."
                )
            kwargs["dt"] = dt = dt * options.adaptive_time_step_multiplier
            result = self.solve_for_psi_squared(**kwargs)
        psi, new_sq_psi = result
        return psi, new_sq_psi, dt

    def update(
        self,state,running_state,dt,*,psi,mu,supercurrent,normal_current,
        induced_vector_potential,applied_vector_potential = None,epsilon= None):
        xp = self.xp
        options = self.options
        operators = self.operators

        
        step = state["step"]
        time = state["time"]
        A_induced = induced_vector_potential
        prev_A_applied = A_applied = applied_vector_potential

        # Update the scalar potential boundary conditions.
        self.update_mu_boundary(time)

        # Update the applied vector potential.
        dA_dt = 0.0
        current_A_applied = self.current_A_applied
        if self.dynamic_vector_potential:
            current_A_applied = self.update_applied_vector_potential(time)
            dA_dt = xp.einsum(
                "ij, ij -> i",
                (current_A_applied - prev_A_applied) / dt,
                self.normalized_directions,
            )
            if xp.any(xp.absolute(dA_dt) > 0):
                # Update the link exponents only if the applied vector potential
                # has actually changed.
                operators.set_link_exponents(current_A_applied)
        else:
            assert A_applied is None
            prev_A_applied = A_applied = current_A_applied

        

        self.current_A_applied = current_A_applied

        # Update the value of epsilon
        epsilon = self.epsilon
        if self.dynamic_epsilon:
            epsilon = self.epsilon = self.update_epsilon(time)

        old_sq_psi = xp.absolute(psi) ** 2
        screening_error = np.inf
        A_induced_vals = [A_induced]
        velocity = [0.0]  # Velocity for Polyak's method
        # This loop runs only once if options.include_screening is False
        for screening_iteration in itertools.count():
            if screening_error < options.screening_tolerance:
                break
            if screening_iteration > options.max_iterations_per_step:
                raise RuntimeError(
                    f"Screening calculation failed to converge at step {step} after"
                    f" {options.max_iterations_per_step} iterations. Relative error in"
                    f" induced vector potential: {screening_error:.2e}"
                    f" (tolerance: {options.screening_tolerance:.2e})."
                )

            # Adjust the time step and calculate the new the order parameter
            if screening_iteration == 0:
                # Find a new time step only for the first screening iteration.
                dt = self.tentative_dt

            if options.include_screening:
                # Update the link variables in the covariant Laplacian and gradient
                # for psi based on the induced vector potential from the previous iteration.
                operators.set_link_exponents(current_A_applied + A_induced)

            # Update the order parameter using an adaptive time step
                
            therm = self.therm_fluc()
            psi, abs_sq_psi, dt = self.adaptive_euler_step(
                step, psi, old_sq_psi, mu, epsilon,therm, dt
            )
            # Update the scalar potential, supercurrent density, and normal current density
            mu, supercurrent, normal_current = self.solve_for_observables(psi, dA_dt)

            if options.include_screening:
                # Evaluate the induced vector potential
                A_induced, screening_error = self.get_induced_vector_potential(
                    supercurrent + normal_current, A_induced_vals, velocity
                )
            else:
                break
        
        running_state.append("dt", dt)
        if self.probe_points is not None:
            # Update the voltage and phase difference
            running_state.append("mu", mu[self.probe_points])
            running_state.append("theta", xp.angle(psi[self.probe_points]))
        if options.include_screening:
            running_state.append("screening_iterations", screening_iteration)

        if options.adaptive:
            # Compute the max abs change in |psi|^2, averaged over the adaptive window,
            # and use it to select a new time step.
            self.d_psi_sq_vals.append(float(xp.absolute(abs_sq_psi - old_sq_psi).max()))
            window = options.adaptive_window
            if step > window:
                new_dt = options.dt_init / max(
                    1e-10, np.mean(self.d_psi_sq_vals[-window:])
                )
                self.tentative_dt = np.clip(0.5 * (new_dt + dt), 0, self.dt_max)

        results = [dt, psi, mu, supercurrent, normal_current, A_induced]
        if self.dynamic_vector_potential:
            results.append(current_A_applied)
        if self.dynamic_epsilon:
            results.append(epsilon)
        return SolverResult(*results)

    def solve_for_observables(self, psi, dA_dt) :
        use_cupy = self.use_cupy
        options = self.options
        use_cupy_solver = options.sparse_solver is SparseSolver.CUPY
        operators = self.operators
        # Compute the supercurrent, scalar potential, and normal current
        supercurrent = (1-self.T)*operators.get_supercurrent(psi)
        rhs = (operators.divergence @ (supercurrent - dA_dt)) - (
            operators.mu_boundary_laplacian @ self.mu_boundary
        )
        if use_cupy and not use_cupy_solver:
            rhs = cupy.asnumpy(rhs)
        if self.options.sparse_solver is SparseSolver.PARDISO:
            mu = pypardiso.spsolve(operators.mu_laplacian, rhs)
        else:
            mu = operators.mu_laplacian_lu(rhs)
        if use_cupy and not use_cupy_solver:
            mu = cupy.asarray(mu)
        normal_current = -(operators.mu_gradient @ mu) - dA_dt
        return mu, supercurrent, normal_current

    def solve(self):
        start_time = datetime.now()
        options = self.options
        options.validate()
        output_file = options.output_file
        seed_solution = self.seed_solution
        num_edges = self.num_edges
        probe_points = self.probe_points

        # Set the initial conditions.
        if self.seed_solution is None:
            parameters = {
                "psi": self.psi_init,
                "mu": self.mu_init,
                "supercurrent": np.zeros(num_edges),
                "normal_current": np.zeros(num_edges),
                "induced_vector_potential": np.zeros((num_edges, 2)),
            }
        else:
            if self.seed_solution.device != self.device:
                raise ValueError(
                    "The seed_solution.device must be equal to the device being simulated."
                )
            seed_data = seed_solution.tdgl_data
            parameters = {
                "psi": seed_data.psi,
                "mu": seed_data.mu,
                # "T": self.T,#modification
                "supercurrent": seed_data.supercurrent,
                "normal_current": seed_data.normal_current,
                "induced_vector_potential": seed_data.induced_vector_potential,
            }

        fixed_values = []
        fixed_names = []
        if self.dynamic_vector_potential:
            parameters["applied_vector_potential"] = self.current_A_applied
        else:
            fixed_values.append(self.current_A_applied)
            fixed_names.append("applied_vector_potential")
        if self.dynamic_epsilon:
            parameters["epsilon"] = self.epsilon
        else:
            fixed_values.append(self.epsilon)
            fixed_names.append("epsilon")

        if self.use_cupy:
            # Move arrays to the GPU
            for key, val in parameters.items():
                parameters[key] = cupy.asarray(val)
            fixed_values = tuple(cupy.asarray(val) for val in fixed_values)

        running_names_and_sizes = {"dt": 1}
        if probe_points is not None:
            running_names_and_sizes["mu"] = len(probe_points)
            running_names_and_sizes["theta"] = len(probe_points)
        if options.include_screening:
            running_names_and_sizes["screening_iterations"] = 1

        with DataHandler(output_file=output_file, logger=logger) as data_handler:
            data_handler.save_mesh(self.device.mesh)
            if data_handler.tmp_file is not None:
                self.device.to_hdf5(
                    data_handler.tmp_file.create_group("solution/device")
                )
            logger.info(
                f"Simulation started at {start_time}"
                f" using sparse solver {options.sparse_solver.value!r}"
                f" and backend {('CuPy' if self.use_cupy else 'NumPy')!r}."
            )
            runner = Runner(
                function=self.update,
                options=options,
                data_handler=data_handler,
                monitor=options.monitor,
                monitor_update_interval=options.monitor_update_interval,
                initial_values=list(parameters.values()),
                names=list(parameters),
                fixed_values=tuple(fixed_values),
                fixed_names=tuple(fixed_names),
                running_names_and_sizes=running_names_and_sizes,
                logger=logger,
            )
            data_was_generated = runner.run()
            end_time = datetime.now()
            logger.info(f"Simulation ended at {end_time}")
            logger.info(f"Simulation took {end_time - start_time}")

            solution = None
            if data_was_generated:
                solution = Solution(
                    device=self.device,
                    path=data_handler.output_path,
                    options=options,
                    applied_vector_potential=self.applied_vector_potential,
                    terminal_currents=self.terminal_currents,
                    disorder_epsilon=self.disorder_epsilon,
                    total_seconds=(end_time - start_time).total_seconds(),
                )
                solution.to_hdf5()
            return solution

# %%
def solveFluc(device, options,applied_vector_potential = 0,terminal_currents= None,
    disorder_epsilon = 1,seed_solution = None,T=0):
    solver = TDGLSolverFluc(
        device=device,
        options=options,
        applied_vector_potential=applied_vector_potential,
        terminal_currents=terminal_currents,
        disorder_epsilon=disorder_epsilon,
        T=T,
        seed_solution=seed_solution
    )
    return solver.solve()

# %% [markdown]
# # KTO Weak Link on the left

# %% [markdown]
# ## Define Device

# %%
length_units = "um"
# Material parameters
xi = 0.02
london_lambda = 2.5
d = 0.005
# Device geometry
total_width = 0.4
total_length = 1.2
# link_width = total_width / 2
# Outer geometry of the film
right_notch = (
    tdgl.Polygon(points=box(total_width,10.3*xi))
    .rotate(0)
    .translate(dx=2.5 * xi)
)
left_notch = (
    tdgl.Polygon(points=box(total_width,10.3*xi))
    .rotate(0)
    .translate(dx=-total_width)
)
# right_notch = left_notch.scale(xfact=-1)
film = (
    tdgl.Polygon("film", points=box(total_width, total_length))
    .difference(right_notch)
    .difference(left_notch)
    .resample(401)#resample vertices so that they are approximately uniformly distributed along the polygon boundary
    .buffer(0)
)
source = (
    tdgl.Polygon("source", points=box(.7 * total_width, total_length / 100))
    .translate(dy=total_length / 2)
)
drain = source.scale(yfact=-1).set_name("drain")
#  Voltage measurement points
probe_points = [(0, total_length/2-3*xi), (0, -total_length/2+3*xi)
                # ,(total_width/2-xi, total_length/2-3*xi), (total_width/2-xi, -total_length/2+3*xi)
                ]

# %%
layer1 = tdgl.Layer(coherence_length=xi, london_lambda=london_lambda, thickness=d, gamma=0.0, u=5.79, conductivity=0.3)
device1 = tdgl.Device(
    "rectangle1",
    layer=layer1,
    film=film,
    #holes=[round_hole, square_hole],
    terminals=[source, drain],
    probe_points=probe_points,
    length_units=length_units,
)

# %%
fig, ax = device1.draw()

# %%
device1.make_mesh(max_edge_length=0.77*xi , smooth=100)
# Out:
# Constructing Voronoi polygons: 100%|██████████| 5697/5697 [00:02<00:00, 2756.16it/s]

# %%
fig, ax = device1.plot(mesh=True, legend=False)
#_ = ax.set_ylim(-7, 7)

# %%
device1.mesh_stats()
# Out:
# <table><tr><b>Mesh Statistics</b></tr><tr><td><b>num_sites</b></td><td>5697</td></tr><tr><td><b>num_elements</b></td><td>10992</td></tr><tr><td><b>min_edge_length</b></td><td>4.748e-03</td></tr><tr><td><b>max_edge_length</b></td><td>1.490e-02</td></tr><tr><td><b>mean_edge_length</b></td><td>9.296e-03</td></tr><tr><td><b>min_area</b></td><td>1.936e-05</td></tr><tr><td><b>max_area</b></td><td>1.435e-04</td></tr><tr><td><b>mean_area</b></td><td>7.159e-05</td></tr><tr><td><b>coherence_length</b></td><td>2.000e-02</td></tr><tr><td><b>length_units</b></td><td>um</td></tr></table>

# %% [markdown]
# ### Define Disorder

# %%
def dis(loc):
    # x,y=loc
    # if y < 5 * xi and y > -5 * xi:
    #     return .9
    return 1

# %% [markdown]
# ## Sweep B and current, save the calculated mean voltage in a dataframe

# %%
current_list = np.append(np.linspace(-0.03, -0.21, 121), 0)
current_list = np.append(current_list, np.linspace(0.03, 0.21, 121))
VvsIvsB = pd.DataFrame({'current':current_list})

for B in range(-200, 200, 25):
    voltage_list = np.array([])

    options0 = tdgl.SolverOptions(
        skip_time = 160,
        solve_time = 90,
        output_file = os.path.join(tempdir.name, f"left-weak-link-{B}mT-field.h5"),
        field_units = "mT",
        current_units = "uA",
        save_every = 800
    )

    seed_solution = solveFluc(
        device1,
        options0,
        terminal_currents=dict(source = current_list[0], drain = -current_list[0]),
        applied_vector_potential = B,
        disorder_epsilon = 1,
        T=0.05

    )

    options1 = tdgl.SolverOptions(
        skip_time = 80,
        solve_time = 90,
        output_file = os.path.join(tempdir.name, f"left-weak-link-{B}mT-field.h5"),
        field_units = "mT",
        current_units = "uA",
        save_every = 800
    )

    for current in current_list:
        if current == 0:
            solution = solveFluc(
                device1,
                options0,
                terminal_currents=dict(source = 0, drain = 0),
                applied_vector_potential = B,
                disorder_epsilon = 1,
                T=0.05
            )
        else:
            solution = solveFluc(
                device1,
                options1,
                terminal_currents=dict(source = current, drain = -current),
                applied_vector_potential = B,
                disorder_epsilon = 1,
                T=0.05,
                seed_solution = seed_solution
            )
        mean_voltage = solution.dynamics.voltage().mean()
        voltage_list = np.append(voltage_list, mean_voltage)
        seed_solution = solution
    
    VvsIvsB[str(B)] = voltage_list
    VvsIvsB.to_csv('left-weak-link-VvsIvsB-new11.csv')

VvsIvsB.set_index('current', inplace = True)
VvsIvsB.sort_index(inplace=True, ascending=True)
VvsIvsB.to_csv('left-weak-link-VvsIvsB-new11.csv')
# Out:
# Thermalizing: 100%|█████████▉| 160/160 [00:32<00:00,  4.97tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.64tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-1.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.86tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.82tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-2.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.89tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.77tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-3.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.96tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.91tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-4.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.82tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.94tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-5.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.99tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.93tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-6.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.93tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.94tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-7.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.93tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.96tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-8.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-9.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-10.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.40tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-11.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-12.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.33tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.08tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-13.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.18tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.07tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-14.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.08tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.21tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-15.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.18tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-16.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.22tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.11tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-17.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.09tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.12tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-18.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.13tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-19.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.14tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-20.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.21tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.15tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-21.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.17tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-22.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.26tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-23.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.21tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-24.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.17tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-25.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.86tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.69tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-26.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.95tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-27.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.91tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.75tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-28.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.69tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.72tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-29.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.82tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.80tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-30.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.86tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.89tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-31.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.17tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.45tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-32.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.58tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-33.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.42tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-34.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.94tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.37tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-35.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.45tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.44tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-36.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.22tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.43tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-37.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.45tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.18tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-38.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-39.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.43tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.43tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-40.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.53tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.47tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-41.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.47tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.48tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-42.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.44tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.45tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-43.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.41tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-44.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.35tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-45.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-46.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.38tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-47.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-48.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.32tau/s ]
# Simulating: 100%|██████████| 90/90 [00:14<00:00,  6.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-49.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.24tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-50.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.33tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-51.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.27tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-52.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.42tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.68tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-53.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.97tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.76tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-54.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.68tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.89tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-55.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.87tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.84tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-56.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.88tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.75tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-57.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.83tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.87tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-58.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.83tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.82tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-59.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.90tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.90tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-60.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.97tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.93tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-61.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.92tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.87tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-62.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.92tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.86tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-63.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.92tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.86tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-64.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.90tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.83tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-65.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.90tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.91tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-66.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.93tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.93tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-67.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.88tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.87tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-68.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.83tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-69.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.70tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.71tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-70.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.81tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.73tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-71.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.74tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-72.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.77tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.72tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-73.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.73tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.68tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-74.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.74tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.74tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-75.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.81tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.74tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-76.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.74tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.84tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-77.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.85tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.80tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-78.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.85tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.78tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-79.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.79tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.90tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-80.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.83tau/s ]
# Simulating: 100%|██████████| 90/90 [00:13<00:00,  6.79tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-81.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.60tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.17tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-82.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.71tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.66tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-83.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.98tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.95tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-84.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.04tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.99tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-85.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.69tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.71tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-86.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.74tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.86tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-87.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:15<00:00,  5.26tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:22<00:00,  4.06tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-88.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:16<00:00,  4.87tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.65tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-89.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.65tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.56tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-90.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.69tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.60tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-91.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.57tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.44tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-92.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.58tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.59tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-93.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.55tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.58tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-94.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.63tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.55tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-95.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.49tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.44tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-96.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.52tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.35tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-97.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.54tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.48tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-98.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.88tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.91tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-99.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.28tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.40tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-100.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-101.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.30tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-102.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.33tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-103.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.26tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.72tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-104.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.09tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:15<00:00,  5.84tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-105.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.28tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.94tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-106.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.27tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-107.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.04tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.00tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-108.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.00tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:16<00:00,  5.51tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-109.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.20tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-110.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.27tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.19tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-111.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.16tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-112.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.26tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.24tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-113.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.20tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.88tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-114.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.15tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:15<00:00,  5.72tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-115.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.91tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.68tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-116.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.99tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:17<00:00,  5.19tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-117.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.83tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:16<00:00,  5.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-118.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.69tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.06tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-119.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:13<00:00,  5.97tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.07tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-120.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:13<00:00,  5.86tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:15<00:00,  5.64tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-121.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.23tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-122.h5.
# Thermalizing: 100%|█████████▉| 160/160 [00:32<00:00,  4.88tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.05tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-123.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.09tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-124.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.84tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.60tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-125.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.97tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-126.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.44tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.50tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-127.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.14tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.18tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-128.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.56tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.15tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-129.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.18tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.12tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-130.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.53tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.46tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-131.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.22tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.08tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-132.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.44tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.50tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-133.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.48tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.56tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-134.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.59tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.46tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-135.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  7.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.12tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-136.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.46tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.53tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-137.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.50tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.51tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-138.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.47tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.77tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-139.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.65tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-140.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.51tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:11<00:00,  7.67tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-141.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.49tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  7.44tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-142.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:10<00:00,  7.43tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:12<00:00,  6.94tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-143.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.75tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-144.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.52tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-145.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:14<00:00,  6.24tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-146.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.61tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.68tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-147.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.69tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.65tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-148.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.66tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.65tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-149.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.62tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-150.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.53tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.56tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-151.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.74tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-152.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.61tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.65tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-153.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.59tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.59tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-154.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.68tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-155.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:11<00:00,  6.68tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.66tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-156.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.59tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:13<00:00,  6.54tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-157.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:12<00:00,  6.34tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.76tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-158.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:14<00:00,  5.63tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.14tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-159.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.62tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-160.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.62tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:25<00:00,  3.56tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-161.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.61tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.67tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-162.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.73tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.82tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-163.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:20<00:00,  3.85tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.83tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-164.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:20<00:00,  3.84tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.77tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-165.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.74tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-166.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-167.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.65tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.62tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-168.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.60tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:25<00:00,  3.57tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-169.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.62tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.69tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-170.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.72tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.78tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-171.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.79tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.86tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-172.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.79tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.75tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-173.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.77tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-174.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.60tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-175.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.64tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.61tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-176.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.57tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:25<00:00,  3.54tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-177.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.61tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.66tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-178.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.78tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.78tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-179.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.78tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.82tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-180.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.79tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.75tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-181.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.75tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-182.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.67tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.65tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-183.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.61tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:25<00:00,  3.58tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-184.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.57tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.61tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-185.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:23<00:00,  3.45tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.73tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-186.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:20<00:00,  3.82tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.78tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-187.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:20<00:00,  3.84tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:23<00:00,  3.84tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-188.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.73tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-189.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.76tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.70tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-190.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:21<00:00,  3.66tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:24<00:00,  3.63tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link--200mT-field-191.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:22<00:00,  3.62tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:25<00:00,  3.56tau/s ]
# ...
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-180.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.27tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.44tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-181.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.28tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-182.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.27tau/s ]
# Simulating: 100%|██████████| 90/90 [00:21<00:00,  4.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-183.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.26tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-184.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.25tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-185.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-186.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-187.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.38tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.23tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-188.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-189.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-190.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.33tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-191.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-192.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-193.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.31tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.25tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-194.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.38tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.27tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-195.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.39tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.35tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-196.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.24tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-197.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.40tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.39tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-198.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-199.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-200.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-201.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.22tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-202.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-203.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.38tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-204.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.37tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-205.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-206.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.31tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-207.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.30tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-208.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:24<00:00,  3.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:39<00:00,  2.28tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-209.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:30<00:00,  2.66tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:30<00:00,  2.92tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-210.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.40tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.38tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-211.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-212.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.30tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.25tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-213.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.23tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-214.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.43tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.40tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-215.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.34tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-216.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-217.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.35tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-218.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.31tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.38tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-219.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.32tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-220.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-221.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.36tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-222.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.24tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-223.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-224.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.36tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.30tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-225.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.30tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-226.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.34tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.20tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-227.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.30tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-228.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.24tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.37tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-229.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.41tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.36tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-230.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-231.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.29tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-232.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.41tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-233.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.29tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.26tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-234.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:17<00:00,  4.46tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.34tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-235.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.38tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-236.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.33tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.39tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-237.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.37tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:21<00:00,  4.25tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-238.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.34tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.38tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-239.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.33tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-240.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.27tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.30tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-241.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.25tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.38tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-242.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.30tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.31tau/s ]
# Output file already exists. Renaming to C:\Users\CARISS~1\AppData\Local\Temp\tmppvvkgfwr\left-weak-link-175mT-field-243.h5.
# Thermalizing: 100%|█████████▉| 80/80 [00:18<00:00,  4.32tau/s ]
# Simulating: 100%|█████████▉| 90/90 [00:20<00:00,  4.36tau/s ]
